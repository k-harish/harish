# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Load the dataset
file_path = r"C:\Users\saiha\OneDrive\Desktop\harish ml\Urban Air Quality and Health Impact Dataset.csv"
data = pd.read_csv(file_path)

# Select relevant features and target variable
# Example features: 'temp', 'humidity', 'Heat_Index', 'Temp_Range', 'Severity_Score'
# Target variable: 'Health_Risk_Score'
features = ['temp', 'humidity', 'Heat_Index', 'Temp_Range', 'Severity_Score']
target = 'Health_Risk_Score'

# Remove any rows with missing values in selected columns
data_clean = data[features + [target]].dropna()

# Split the data into training and testing sets
X = data_clean[features]
y = data_clean[target]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initialize and train the linear regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = model.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error (MSE):", mse)
print("R-squared (R2) score:", r2)

# Display the model coefficients
print("Model Coefficients:", model.coef_)
print("Model Intercept:", model.intercept_)
# Out:
# Mean Squared Error (MSE): 0.017141987890006104
# R-squared (R2) score: 0.9605358422401551
# Model Coefficients: [-0.00062285  0.03134458  0.09711089  0.00496251  0.56546215]
# Model Intercept: -1.6040785432162696

# %%
data
# Out:
#        datetime  datetimeEpoch     tempmax    tempmin       temp  \
# 0    2024-09-07   1.725692e+09  106.100000  91.000000  98.500000
# 1    2024-09-08   1.725779e+09  103.900000  87.000000  95.400000
# 2    2024-09-09   1.725865e+09  105.000000  83.900000  94.700000
# 3    2024-09-10   1.725952e+09  106.100000  81.200000  93.900000
# 4    2024-09-11   1.726038e+09  106.100000  82.100000  94.000000
# ..          ...            ...         ...        ...        ...
# 995  2024-09-18   1.726633e+09   76.060546  64.359387  69.002142
# 996  2024-09-17   1.726550e+09   68.409198  65.939319  66.567410
# 997  2024-09-12   1.726122e+09   69.756690  65.286919  65.919492
# 998  2024-09-14   1.726284e+09   77.106797  61.481724  68.106569
# 999  2024-09-18   1.726618e+09   90.923080  79.296868  81.636991
#
#      feelslikemax  feelslikemin  feelslike        dew   humidity  ...  \
# 0      104.000000     88.100000  95.900000  51.500000  21.000000  ...
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Load the dataset
file_path = r"C:\Users\saiha\OneDrive\Desktop\harish ml\Urban Air Quality and Health Impact Dataset.csv"
data = pd.read_csv(file_path)

# Select relevant features and target variable
features = ['temp', 'humidity', 'Heat_Index', 'Temp_Range', 'Severity_Score']
target = 'Health_Risk_Score'

# Remove any rows with missing values in selected columns
data_clean = data[features + [target]].dropna()

# Split the data into training and testing sets
X = data_clean[features]
y = data_clean[target]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initialize and train the linear regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = model.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Squared Error (MSE):", mse)
print("R-squared (R2) score:", r2)
print("Model Coefficients:", model.coef_)
print("Model Intercept:", model.intercept_)

# Data Visualization

# 1. Scatter plot with regression line for a single feature (e.g., 'temp')
def scatter_with_regression(X_test, y_test, y_pred, feature):
    plt.scatter(X_test[feature], y_test, color='blue', label='Actual')
    plt.scatter(X_test[feature], y_pred, color='red', label='Predicted', alpha=0.5)
    plt.xlabel(feature)
    plt.ylabel(target)
    plt.title(f'Scatter Plot with Regression Line ({feature})')
    plt.legend()
    plt.show()

# 2. Feature distribution histograms
def plot_histograms(data):
    data.hist(bins=20, figsize=(10, 8), color='skyblue')
    plt.tight_layout()
    plt.show()

# 3. Correlation heatmap
def plot_correlation_heatmap(data):
    plt.figure(figsize=(10, 8))
    corr = data.corr()
    sns.heatmap(corr, annot=True, cmap="coolwarm", linewidths=0.5)
    plt.title("Correlation Heatmap")
    plt.show()

# 4. Residual plot
def plot_residuals(y_test, y_pred):
    residuals = y_test - y_pred
    plt.scatter(y_pred, residuals)
    plt.axhline(y=0, color='red', linestyle='--')
    plt.xlabel("Predicted")
    plt.ylabel("Residuals")
    plt.title("Residual Plot")
    plt.show()

# Call the visualization functions

# 1. Scatter plot with regression line for 'temp'
scatter_with_regression(X_test, y_test, y_pred, 'temp')

# 2. Histograms for feature distributions
plot_histograms(data_clean)

# 3. Correlation heatmap
plot_correlation_heatmap(data_clean)

# 4. Residual plot
plot_residuals(y_test, y_pred)
# Out:
# Mean Squared Error (MSE): 0.017141987890006104
# R-squared (R2) score: 0.9605358422401551
# Model Coefficients: [-0.00062285  0.03134458  0.09711089  0.00496251  0.56546215]
# Model Intercept: -1.6040785432162696

# %%
import joblib

# Save the trained model to a file
model_filename = 'linear_regression_model.pkl'
joblib.dump(model, model_filename)

print(f"Model saved as {model_filename}")
# Out:
# Model saved as linear_regression_model.pkl
